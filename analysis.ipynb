# %%
import pandas as pd

df = pd.read_csv('./tono_assessment.csv', delimiter=';')
# Remove the ../../src/data/TONO/release/ prefix from the Filename column rows
df['Filename'] = df['Filename'].str.replace(r'../../src/data/TONO/release/', '', regex=True)
# Remove the .wav suffix from the Filename column rows
df
# Out:
#                                                Filename  UnifiedQualityScore  \
# 0     la_2/S932980426-GM-A79-EME-T14-S1-LH-C1-I0014-...            29.081543
# 1     la_2/S397228464-GF-A72-EEA-T03-S1-LH-C1-I0009-...            25.214190
# 2     la_2/S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-...            25.578022
# 3     la_2/S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-...            22.214788
# 4     la_2/S334613033-GM-A58-EAF-T14-S1-LH-C1-I0047-...            27.890985
# ...                                                 ...                  ...
# 4564  pixel/S664246838-GF-A21-EEA-T11-S1-LH-C1-I0004...            22.968184
# 4565  pixel/S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006...            19.858953
# 4566  pixel/S962503135-GF-A84-EEA-T14-S1-LH-C1-I0013...            24.254084
# 4567  pixel/S415761895-GF-A62-EAS-T03-S1-LH-C1-I0005...            25.427649
# 4568  pixel/S179182026-GM-A47-EEA-T11-S1-LH-C1-I0041...            29.184067
#
#       BackgroundUniformity  IlluminationUniformity  LuminanceMean  \
# 0                23.828460                0.238281       0.310215
# 1                39.603437                0.209105       0.417505
# 2                32.657118                0.213958       0.476616
# 3                34.988555                0.037551       0.447007
# 4                45.059756                0.282007       0.260269
# ...                    ...                     ...            ...
# 4564             49.203864                0.000000       0.384795
# 4565             34.097942                0.079620       0.349573
# 4566             69.027712                0.347755       0.407682
# 4567             25.253495                0.516204       0.471743
# 4568             36.674290                0.157025       0.384651
#
#       LuminanceVariance  UnderExposurePrevention  OverExposurePrevention  \
# 0              0.043742                 0.233351                     0.0
# 1              0.042918                 0.054696                     0.0
# 2              0.035719                 0.039281                     0.0
# 3              0.040772                 0.057592                     0.0
# 4              0.047316                 0.348876                     0.0
# ...                 ...                      ...                     ...
# 4564           0.044207                 0.074837                     0.0
# 4565           0.040303                 0.075974                     0.0
# 4566           0.037953                 0.063919                     0.0
# 4567           0.031344                 0.047019                     0.0
# 4568           0.032948                 0.064095                     0.0
#
#       DynamicRange  Sharpness  ...  RightwardCropOfTheFaceImage.scalar  \
# 0         7.463093         46  ...                                 100
# 1         7.614437         47  ...                                 100
# 2         7.488843         46  ...                                 100
# 3         7.537620         47  ...                                 100
# 4         7.329834         47  ...                                 100
# ...            ...        ...  ...                                 ...
# 4564      7.505501         33  ...                                 100
# 4565      7.540595        -20  ...                                 100
# 4566      7.549772         14  ...                                 100
# 4567      7.346300         16  ...                                 100
# 4568      7.449913         36  ...                                 100
#
#       MarginAboveOfTheFaceImage.scalar  MarginBelowOfTheFaceImage.scalar  \
# 0                                    6                                 2
# 1                                   27                                97
# 2                                   12                                77
# 3                                   63                                86
# 4                                    7                                37
# ...                                ...                               ...
# 4564                                14                                28
# 4565                                70                                59
# 4566                                86                                63
# 4567                                48                                 9
# 4568                                 7                                 7
#
#       HeadPoseYaw.scalar  HeadPosePitch.scalar  HeadPoseRoll.scalar  \
# 0                    100                    98                  100
# 1                    100                   100                  100
# 2                    100                   100                  100
# 3                    100                    95                  100
# 4                    100                   100                  100
# ...                  ...                   ...                  ...
# 4564                 100                    98                  100
# 4565                 100                    99                  100
# 4566                 100                    99                  100
# 4567                 100                   100                  100
# 4568                 100                   100                  100
#
#       ExpressionNeutrality.scalar  NoHeadCoverings.scalar  \
# 0                              95                     100
# 1                              98                     100
# 2                              98                     100
# 3                              98                     100
# 4                              96                     100
# ...                           ...                     ...
# 4564                           97                     100
# 4565                           98                     100
# 4566                           98                     100
# 4567                           98                     100
# 4568                           99                     100
#
#       assessment_time_in_ms  Unnamed: 58
# 0                       677          NaN
# 1                       504          NaN
# 2                       443          NaN
# 3                       462          NaN
# 4                       434          NaN
# ...                     ...          ...
# 4564                    434          NaN
# 4565                    459          NaN
# 4566                    461          NaN
# 4567                    528          NaN
# 4568                    575          NaN
#
# [4569 rows x 59 columns]
