# %% [markdown]
# # Data Prepocessing

# %% [markdown]
# ## TONO Dataset Quality Assessment

# %% [markdown]
# Output of the quality assesment on the TONO dataset

# %%
import pandas as pd

df = pd.read_csv('src/data/QFIQ_assessment/tono_assessment.csv', delimiter=';')
# Remove the ../../src/data/TONO/release/ prefix from the Filename column rows
df['Filename'] = df['Filename'].str.replace(r'../../src/data/TONO/release/', '', regex=True)
df['ContrastElement'] = df['Filename'].str.split('/').str[0]
df['Filename'] = df['Filename'].str.replace(r'^[^/]+/', '', regex=True)
df
# Out:
#                                               Filename  UnifiedQualityScore  \
# 0     S932980426-GM-A79-EME-T14-S1-LH-C1-I0014-F00.png            29.081543
# 1     S397228464-GF-A72-EEA-T03-S1-LH-C1-I0009-F00.png            25.214190
# 2     S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            25.578022
# 3     S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            22.214788
# 4     S334613033-GM-A58-EAF-T14-S1-LH-C1-I0047-F00.png            27.890985
# ...                                                ...                  ...
# 4564  S664246838-GF-A21-EEA-T11-S1-LH-C1-I0004-F00.png            22.968184
# 4565  S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png            19.858953
# 4566  S962503135-GF-A84-EEA-T14-S1-LH-C1-I0013-F00.png            24.254084
# 4567  S415761895-GF-A62-EAS-T03-S1-LH-C1-I0005-F00.png            25.427649
# 4568  S179182026-GM-A47-EEA-T11-S1-LH-C1-I0041-F00.png            29.184067
#
#       BackgroundUniformity  IlluminationUniformity  LuminanceMean  \
# 0                23.828460                0.238281       0.310215
# 1                39.603437                0.209105       0.417505
# 2                32.657118                0.213958       0.476616
# 3                34.988555                0.037551       0.447007
# 4                45.059756                0.282007       0.260269
# ...                    ...                     ...            ...
# 4564             49.203864                0.000000       0.384795
# 4565             34.097942                0.079620       0.349573
# 4566             69.027712                0.347755       0.407682
# 4567             25.253495                0.516204       0.471743
# 4568             36.674290                0.157025       0.384651
#
#       LuminanceVariance  UnderExposurePrevention  OverExposurePrevention  \
# 0              0.043742                 0.233351                     0.0
# 1              0.042918                 0.054696                     0.0
# 2              0.035719                 0.039281                     0.0
# 3              0.040772                 0.057592                     0.0
# 4              0.047316                 0.348876                     0.0
# ...                 ...                      ...                     ...
# 4564           0.044207                 0.074837                     0.0
# 4565           0.040303                 0.075974                     0.0
# 4566           0.037953                 0.063919                     0.0
# 4567           0.031344                 0.047019                     0.0
# 4568           0.032948                 0.064095                     0.0
#
#       DynamicRange  Sharpness  ...  MarginAboveOfTheFaceImage.scalar  \
# 0         7.463093         46  ...                                 6
# 1         7.614437         47  ...                                27
# 2         7.488843         46  ...                                12
# 3         7.537620         47  ...                                63
# 4         7.329834         47  ...                                 7
# ...            ...        ...  ...                               ...
# 4564      7.505501         33  ...                                14
# 4565      7.540595        -20  ...                                70
# 4566      7.549772         14  ...                                86
# 4567      7.346300         16  ...                                48
# 4568      7.449913         36  ...                                 7
#
#       MarginBelowOfTheFaceImage.scalar  HeadPoseYaw.scalar  \
# 0                                    2                 100
# 1                                   97                 100
# 2                                   77                 100
# 3                                   86                 100
# 4                                   37                 100
# ...                                ...                 ...
# 4564                                28                 100
# 4565                                59                 100
# 4566                                63                 100
# 4567                                 9                 100
# 4568                                 7                 100
#
#       HeadPosePitch.scalar  HeadPoseRoll.scalar  ExpressionNeutrality.scalar  \
# 0                       98                  100                           95
# 1                      100                  100                           98
# 2                      100                  100                           98
# 3                       95                  100                           98
# 4                      100                  100                           96
# ...                    ...                  ...                          ...
# 4564                    98                  100                           97
# 4565                    99                  100                           98
# 4566                    99                  100                           98
# 4567                   100                  100                           98
# 4568                   100                  100                           99
#
#       NoHeadCoverings.scalar  assessment_time_in_ms  Unnamed: 58  \
# 0                        100                    677          NaN
# 1                        100                    504          NaN
# 2                        100                    443          NaN
# 3                        100                    462          NaN
# 4                        100                    434          NaN
# ...                      ...                    ...          ...
# 4564                     100                    434          NaN
# 4565                     100                    459          NaN
# 4566                     100                    461          NaN
# 4567                     100                    528          NaN
# 4568                     100                    575          NaN
#
#       ContrastElement
# 0                la_2
# 1                la_2
# 2                la_2
# 3                la_2
# 4                la_2
# ...               ...
# 4564            pixel
# 4565            pixel
# 4566            pixel
# 4567            pixel
# 4568            pixel
#
# [4569 rows x 60 columns]

# %% [markdown]
# ## ONOT Dataset Quality Assessment

# %% [markdown]
# 21 images were assessed from the ONOT dataset as they are ICAO-compliant and therefore can provide the LLM with the larger spectrum of references to what is acceptable

# %%
# Show the output of the ONOT assessment
df_onot = pd.read_csv('src/data/QFIQ_assessment/onot_assessment.csv', delimiter=';')
# Remove the ../../src/data/TONO/release/ prefix from the Filename column rows
df_onot['Filename'] = df_onot['Filename'].str.replace(r'../../src/data/ONOT/S115379105/', '', regex=True)

# When the ContrastElement is None, we rename it to 'ONOT'
df_onot['ContrastElement'] = 'ONOT'

df_onot
# Out:
#                                             Filename  UnifiedQualityScore  \
# 0   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0019-F00.png            24.694574
# 1   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0005-F00.png            27.582806
# 2   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0043-F00.png            25.664064
# 3   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0038-F00.png            26.245668
# 4   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0022-F00.png            24.825676
# 5   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0030-F00.png            26.221226
# 6   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0027-F00.png            26.825811
# 7   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0026-F00.png            24.972778
# 8   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0054-F00.png            25.945904
# 9   S115379105-GF-A98-EEA-T14-S1-LH-C1-I0062-F00.png            21.362080
# 10  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0051-F00.png            27.609344
# 11  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0034-F00.png            23.789949
# 12  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0000-F00.png            24.971827
# 13  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0001-F00.png            25.730030
# 14  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0044-F00.png            24.563148
# 15  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0023-F00.png            25.374035
# 16  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0024-F00.png            25.057383
# 17  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0050-F00.png            24.011099
# 18  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0013-F00.png            26.500957
# 19  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0032-F00.png            24.203373
# 20  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0048-F00.png            23.942284
#
#     BackgroundUniformity  IlluminationUniformity  LuminanceMean  \
# 0              30.576659                0.209796       0.351990
# 1              26.069389                0.088980       0.473496
# 2              31.310287                0.022377       0.425357
# 3              25.106617                0.056327       0.387922
# 4              23.147718                0.096886       0.399669
# 5              25.730682                0.060957       0.396901
# 6              17.516458                0.248163       0.431905
# 7              26.250802                0.006944       0.398501
# 8              24.416622                0.091821       0.429741
# 9              29.054647                0.030093       0.366042
# 10             22.297748                0.272653       0.381283
# 11             27.270439                0.452245       0.500743
# 12             14.363907                0.072653       0.448046
# 13             38.961191                0.048611       0.413098
# 14             34.133660                0.097959       0.389917
# 15             19.770021                0.015340       0.390850
# 16             25.175117                0.000000       0.432519
# 17             31.670131                0.163580       0.451682
# 18             30.068117                0.083045       0.404002
# 19             33.185286                0.017747       0.431081
# 20             22.397379                0.015432       0.419159
#
#     LuminanceVariance  UnderExposurePrevention  OverExposurePrevention  \
# 0            0.037411                 0.072875                       0
# 1            0.042209                 0.027129                       0
# 2            0.050598                 0.035824                       0
# 3            0.057796                 0.082652                       0
# 4            0.032792                 0.053494                       0
# 5            0.052038                 0.063378                       0
# 6            0.040728                 0.040559                       0
# 7            0.048955                 0.069995                       0
# 8            0.046910                 0.062906                       0
# 9            0.052096                 0.071313                       0
# 10           0.048866                 0.070661                       0
# 11           0.028741                 0.013224                       0
# 12           0.056439                 0.032017                       0
# 13           0.046869                 0.049918                       0
# 14           0.036555                 0.069302                       0
# 15           0.047927                 0.060969                       0
# 16           0.059289                 0.057994                       0
# 17           0.043072                 0.035396                       0
# 18           0.051489                 0.063749                       0
# 19           0.060765                 0.059662                       0
# 20           0.051561                 0.054789                       0
#
#     DynamicRange  Sharpness  ...  MarginAboveOfTheFaceImage.scalar  \
# 0       7.476407         26  ...                                38
# 1       7.543368         50  ...                                52
# 2       7.540373         43  ...                                27
# 3       7.665561         41  ...                                 7
# 4       7.404202         45  ...                                25
# 5       7.592719         49  ...                                37
# 6       7.560346         43  ...                                29
# 7       7.556282         39  ...                                17
# 8       7.657486         45  ...                                10
# 9       7.498804         44  ...                                24
# 10      7.549413         46  ...                                27
# 11      7.397205         48  ...                                20
# 12      7.505161         48  ...                                48
# 13      7.479059         41  ...                                22
# 14      7.517520         48  ...                                17
# 15      7.539296         41  ...                                10
# 16      7.568437         48  ...                                20
# 17      7.580549         43  ...                                38
# 18      7.594698         44  ...                                10
# 19      7.688375         43  ...                                16
# 20      7.578197         47  ...                                 2
#
#     MarginBelowOfTheFaceImage.scalar  HeadPoseYaw.scalar  \
# 0                                100                 100
# 1                                 91                 100
# 2                                100                 100
# 3                                 83                 100
# 4                                100                 100
# 5                                 98                  99
# 6                                 87                 100
# 7                                 61                 100
# 8                                 70                 100
# 9                                 99                  98
# 10                               100                 100
# 11                               100                 100
# 12                                82                 100
# 13                                94                 100
# 14                                73                 100
# 15                                98                  99
# 16                                86                 100
# 17                               100                 100
# 18                                90                 100
# 19                                98                 100
# 20                               100                 100
#
#     HeadPosePitch.scalar  HeadPoseRoll.scalar  ExpressionNeutrality.scalar  \
# 0                     99                  100                           97
# 1                     99                  100                           98
# 2                    100                  100                           97
# 3                    100                  100                           97
# 4                    100                  100                           98
# 5                    100                  100                           99
# 6                    100                  100                           97
# 7                     99                  100                           97
# 8                    100                  100                           96
# 9                     99                  100                           98
# 10                    99                  100                           93
# 11                    99                  100                           99
# 12                   100                  100                           97
# 13                   100                  100                           97
# 14                    98                  100                           98
# 15                   100                  100                           97
# 16                    99                  100                           98
# 17                   100                  100                           98
# 18                   100                  100                           98
# 19                   100                  100                           97
# 20                   100                  100                           96
#
#     NoHeadCoverings.scalar  assessment_time_in_ms  Unnamed: 58  \
# 0                      100                    794          NaN
# 1                      100                    596          NaN
# 2                      100                    550          NaN
# 3                      100                    615          NaN
# 4                      100                    620          NaN
# 5                      100                    622          NaN
# 6                      100                    629          NaN
# 7                      100                    517          NaN
# 8                      100                    545          NaN
# 9                      100                    650          NaN
# 10                     100                    641          NaN
# 11                     100                    530          NaN
# 12                     100                    581          NaN
# 13                     100                    565          NaN
# 14                     100                    443          NaN
# 15                     100                    495          NaN
# 16                     100                    435          NaN
# 17                     100                    443          NaN
# 18                     100                    437          NaN
# 19                     100                    475          NaN
# 20                     100                    468          NaN
#
#     ContrastElement
# 0              ONOT
# 1              ONOT
# 2              ONOT
# 3              ONOT
# 4              ONOT
# 5              ONOT
# 6              ONOT
# 7              ONOT
# 8              ONOT
# 9              ONOT
# 10             ONOT
# 11             ONOT
# 12             ONOT
# 13             ONOT
# 14             ONOT
# 15             ONOT
# 16             ONOT
# 17             ONOT
# 18             ONOT
# 19             ONOT
# 20             ONOT
#
# [21 rows x 60 columns]

# %% [markdown]
# Merging TONO and ONOT assessments

# %%
# Merge the two dataframes
df_combined = pd.concat([df, df_onot], ignore_index=True)
# Move the ContrastElement as a second column
df_combined = df_combined[['Filename', 'ContrastElement'] + [col for col in df_combined.columns if col not in ['Filename', 'ContrastElement']]]
df_combined
# Out:
#                                               Filename ContrastElement  \
# 0     S932980426-GM-A79-EME-T14-S1-LH-C1-I0014-F00.png            la_2
# 1     S397228464-GF-A72-EEA-T03-S1-LH-C1-I0009-F00.png            la_2
# 2     S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_2
# 3     S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_2
# 4     S334613033-GM-A58-EAF-T14-S1-LH-C1-I0047-F00.png            la_2
# ...                                                ...             ...
# 4585  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0024-F00.png            ONOT
# 4586  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0050-F00.png            ONOT
# 4587  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0013-F00.png            ONOT
# 4588  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0032-F00.png            ONOT
# 4589  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0048-F00.png            ONOT
#
#       UnifiedQualityScore  BackgroundUniformity  IlluminationUniformity  \
# 0               29.081543             23.828460                0.238281
# 1               25.214190             39.603437                0.209105
# 2               25.578022             32.657118                0.213958
# 3               22.214788             34.988555                0.037551
# 4               27.890985             45.059756                0.282007
# ...                   ...                   ...                     ...
# 4585            25.057383             25.175117                0.000000
# 4586            24.011099             31.670131                0.163580
# 4587            26.500957             30.068117                0.083045
# 4588            24.203373             33.185286                0.017747
# 4589            23.942284             22.397379                0.015432
#
#       LuminanceMean  LuminanceVariance  UnderExposurePrevention  \
# 0          0.310215           0.043742                 0.233351
# 1          0.417505           0.042918                 0.054696
# 2          0.476616           0.035719                 0.039281
# 3          0.447007           0.040772                 0.057592
# 4          0.260269           0.047316                 0.348876
# ...             ...                ...                      ...
# 4585       0.432519           0.059289                 0.057994
# 4586       0.451682           0.043072                 0.035396
# 4587       0.404002           0.051489                 0.063749
# 4588       0.431081           0.060765                 0.059662
# 4589       0.419159           0.051561                 0.054789
#
#       OverExposurePrevention  DynamicRange  ...  \
# 0                        0.0      7.463093  ...
# 1                        0.0      7.614437  ...
# 2                        0.0      7.488843  ...
# 3                        0.0      7.537620  ...
# 4                        0.0      7.329834  ...
# ...                      ...           ...  ...
# 4585                     0.0      7.568437  ...
# 4586                     0.0      7.580549  ...
# 4587                     0.0      7.594698  ...
# 4588                     0.0      7.688375  ...
# 4589                     0.0      7.578197  ...
#
#       RightwardCropOfTheFaceImage.scalar  MarginAboveOfTheFaceImage.scalar  \
# 0                                    100                                 6
# 1                                    100                                27
# 2                                    100                                12
# 3                                    100                                63
# 4                                    100                                 7
# ...                                  ...                               ...
# 4585                                 100                                20
# 4586                                 100                                38
# 4587                                 100                                10
# 4588                                 100                                16
# 4589                                 100                                 2
#
#       MarginBelowOfTheFaceImage.scalar  HeadPoseYaw.scalar  \
# 0                                    2                 100
# 1                                   97                 100
# 2                                   77                 100
# 3                                   86                 100
# 4                                   37                 100
# ...                                ...                 ...
# 4585                                86                 100
# 4586                               100                 100
# 4587                                90                 100
# 4588                                98                 100
# 4589                               100                 100
#
#       HeadPosePitch.scalar  HeadPoseRoll.scalar  ExpressionNeutrality.scalar  \
# 0                       98                  100                           95
# 1                      100                  100                           98
# 2                      100                  100                           98
# 3                       95                  100                           98
# 4                      100                  100                           96
# ...                    ...                  ...                          ...
# 4585                    99                  100                           98
# 4586                   100                  100                           98
# 4587                   100                  100                           98
# 4588                   100                  100                           97
# 4589                   100                  100                           96
#
#       NoHeadCoverings.scalar  assessment_time_in_ms  Unnamed: 58
# 0                        100                    677          NaN
# 1                        100                    504          NaN
# 2                        100                    443          NaN
# 3                        100                    462          NaN
# 4                        100                    434          NaN
# ...                      ...                    ...          ...
# 4585                     100                    435          NaN
# 4586                     100                    443          NaN
# 4587                     100                    437          NaN
# 4588                     100                    475          NaN
# 4589                     100                    468          NaN
#
# [4590 rows x 60 columns]

# %% [markdown]
# Keep only the columns that output the scalar values, file names, and contrast elements

# %%
cols_to_keep = ['Filename', 'ContrastElement'] + [col for col in df_combined.columns if col.endswith('scalar')]
df_combined = df_combined[cols_to_keep]
df_combined
# Out:
#                                               Filename ContrastElement  \
# 0     S932980426-GM-A79-EME-T14-S1-LH-C1-I0014-F00.png            la_2
# 1     S397228464-GF-A72-EEA-T03-S1-LH-C1-I0009-F00.png            la_2
# 2     S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_2
# 3     S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_2
# 4     S334613033-GM-A58-EAF-T14-S1-LH-C1-I0047-F00.png            la_2
# ...                                                ...             ...
# 4585  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0024-F00.png            ONOT
# 4586  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0050-F00.png            ONOT
# 4587  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0013-F00.png            ONOT
# 4588  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0032-F00.png            ONOT
# 4589  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0048-F00.png            ONOT
#
#       UnifiedQualityScore.scalar  BackgroundUniformity.scalar  \
# 0                             91                           88
# 1                             70                           81
# 2                             73                           84
# 3                             43                           83
# 4                             87                           79
# ...                          ...                          ...
# 4585                          69                           88
# 4586                          60                           85
# 4587                          79                           85
# 4588                          61                           84
# 4589                          59                           89
#
#       IlluminationUniformity.scalar  LuminanceMean.scalar  \
# 0                                65                    90
# 1                                63                    99
# 2                                63                    99
# 3                                37                    99
# 4                                68                    77
# ...                             ...                   ...
# 4585                              0                    99
# 4586                             58                    99
# 4587                             47                    98
# 4588                             30                    99
# 4589                             29                    99
#
#       LuminanceVariance.scalar  UnderExposurePrevention.scalar  \
# 0                           76                             100
# 1                           77                             100
# 2                           84                             100
# 3                           79                             100
# 4                           73                             100
# ...                        ...                             ...
# 4585                        64                             100
# 4586                        77                             100
# 4587                        69                             100
# 4588                        63                             100
# 4589                        69                             100
#
#       OverExposurePrevention.scalar  DynamicRange.scalar  ...  \
# 0                               100                   93  ...
# 1                               100                   95  ...
# 2                               100                   94  ...
# 3                               100                   94  ...
# 4                               100                   92  ...
# ...                             ...                  ...  ...
# 4585                            100                   95  ...
# 4586                            100                   95  ...
# 4587                            100                   95  ...
# 4588                            100                   96  ...
# 4589                            100                   95  ...
#
#       HeadSize.scalar  LeftwardCropOfTheFaceImage.scalar  \
# 0                  51                                100
# 1                   8                                100
# 2                  14                                100
# 3                   8                                100
# 4                  22                                100
# ...               ...                                ...
# 4585               11                                100
# 4586                2                                100
# 4587               12                                100
# 4588                8                                100
# 4589                9                                100
#
#       RightwardCropOfTheFaceImage.scalar  MarginAboveOfTheFaceImage.scalar  \
# 0                                    100                                 6
# 1                                    100                                27
# 2                                    100                                12
# 3                                    100                                63
# 4                                    100                                 7
# ...                                  ...                               ...
# 4585                                 100                                20
# 4586                                 100                                38
# 4587                                 100                                10
# 4588                                 100                                16
# 4589                                 100                                 2
#
#       MarginBelowOfTheFaceImage.scalar  HeadPoseYaw.scalar  \
# 0                                    2                 100
# 1                                   97                 100
# 2                                   77                 100
# 3                                   86                 100
# 4                                   37                 100
# ...                                ...                 ...
# 4585                                86                 100
# 4586                               100                 100
# 4587                                90                 100
# 4588                                98                 100
# 4589                               100                 100
#
#       HeadPosePitch.scalar  HeadPoseRoll.scalar  ExpressionNeutrality.scalar  \
# 0                       98                  100                           95
# 1                      100                  100                           98
# 2                      100                  100                           98
# 3                       95                  100                           98
# 4                      100                  100                           96
# ...                    ...                  ...                          ...
# 4585                    99                  100                           98
# 4586                   100                  100                           98
# 4587                   100                  100                           98
# 4588                   100                  100                           97
# 4589                   100                  100                           96
#
#       NoHeadCoverings.scalar
# 0                        100
# 1                        100
# 2                        100
# 3                        100
# 4                        100
# ...                      ...
# 4585                     100
# 4586                     100
# 4587                     100
# 4588                     100
# 4589                     100
#
# [4590 rows x 30 columns]

# %% [markdown]
# For each of the contrast element group, 6 images will be chosen with the variety of the utility score for providing the testing base for the LLM. Additionally 6 images from the ONOT database were chosen.

# %%
# In each of the contrast elements group, get 3 images with the highest UnifiedQualityScore.scalar, 3 with the lowest UnifiedQualityScore.scalar, and 3 with the median UnifiedQualityScore.scalar. or closest to it.
def get_top_bottom_median(group):
    top = group.nlargest(2, 'UnifiedQualityScore.scalar')
    bottom = group.nsmallest(2, 'UnifiedQualityScore.scalar')
    median_value = group['UnifiedQualityScore.scalar'].median()
    median = group.iloc[(group['UnifiedQualityScore.scalar'] - median_value).abs().argsort()[:2]]
    
    return pd.concat([top, bottom, median])

# Apply the function to each group of ContrastElement
df_in_context_train = df_combined.groupby('ContrastElement').apply(get_top_bottom_median).reset_index(drop=True)


# Save the resulting DataFrame to a CSV file
df_in_context_train.to_csv('src/data/QFIQ_assessment/tono_assessment_contrast_element_test.csv', index=False)
# Out:
# /tmp/ipykernel_4127/347421143.py:11: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_in_context_train = df_combined.groupby('ContrastElement').apply(get_top_bottom_median).reset_index(drop=True)

# %% [markdown]
# # In-context learning

# %% [markdown]
# ### Train data preparation

# %% [markdown]
# The goal is to provide the descriptions for the train data, so that they can be used for prompting LLM for in-context learning.

# %%
# Read the saved CSV file
df_in_context_train = pd.read_csv('src/data/QFIQ_assessment/tono_assessment_contrast_element_test.csv')
df_in_context_train
# Out:
#                                              Filename ContrastElement  \
# 0    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0005-F00.png            ONOT
# 1    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0051-F00.png            ONOT
# 2    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0062-F00.png            ONOT
# 3    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0034-F00.png            ONOT
# 4    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0024-F00.png            ONOT
# ..                                                ...             ...
# 103  S248968574-GM-A81-EAS-T14-S1-LH-C1-I0022-F00.png            zoom
# 104  S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png            zoom
# 105  S265934537-GF-A26-EAS-T14-S1-LH-C1-I0063-F00.png            zoom
# 106  S220036139-GF-A33-EME-T14-S1-LH-C1-I0048-F00.png            zoom
# 107  S289919415-GF-A46-EEA-T14-S1-LH-C1-I0060-F00.png            zoom
#
#      UnifiedQualityScore.scalar  BackgroundUniformity.scalar  \
# 0                            85                           87
# 1                            85                           89
# 2                            35                           86
# 3                            58                           87
# 4                            69                           88
# ..                          ...                          ...
# 103                          93                           58
# 104                          23                           74
# 105                          25                           66
# 106                          74                           81
# 107                          74                           59
#
#      IlluminationUniformity.scalar  LuminanceMean.scalar  \
# 0                               48                    99
# 1                               68                    97
# 2                               35                    96
# 3                               79                   100
# 4                                0                    99
# ..                             ...                   ...
# 103                             84                    97
# 104                             50                    95
# 105                             91                    99
# 106                             56                    99
# 107                             79                    99
#
#      LuminanceVariance.scalar  UnderExposurePrevention.scalar  \
# 0                          78                             100
# 1                          72                             100
# 2                          69                             100
# 3                          91                             100
# 4                          64                             100
# ..                        ...                             ...
# 103                        98                             100
# 104                        79                             100
# 105                        96                             100
# 106                        82                             100
# 107                        92                             100
#
#      OverExposurePrevention.scalar  DynamicRange.scalar  ...  HeadSize.scalar  \
# 0                              100                   94  ...                8
# 1                              100                   94  ...                5
# 2                              100                   94  ...                7
# 3                              100                   92  ...                3
# 4                              100                   95  ...               11
# ..                             ...                  ...  ...              ...
# 103                            100                   91  ...               26
# 104                            100                   94  ...               83
# 105                            100                   89  ...               67
# 106                            100                   94  ...               88
# 107                            100                   92  ...               53
#
#      LeftwardCropOfTheFaceImage.scalar  RightwardCropOfTheFaceImage.scalar  \
# 0                                  100                                 100
# 1                                  100                                 100
# 2                                  100                                 100
# 3                                  100                                 100
# 4                                  100                                 100
# ..                                 ...                                 ...
# 103                                100                                 100
# 104                                100                                 100
# 105                                100                                 100
# 106                                100                                 100
# 107                                100                                 100
#
#      MarginAboveOfTheFaceImage.scalar  MarginBelowOfTheFaceImage.scalar  \
# 0                                  52                                91
# 1                                  27                               100
# 2                                  24                                99
# 3                                  20                               100
# 4                                  20                                86
# ..                                ...                               ...
# 103                                 0                                 1
# 104                                 0                                 4
# 105                                 1                                 0
# 106                                 0                                17
# 107                                 0                                 2
#
#      HeadPoseYaw.scalar  HeadPosePitch.scalar  HeadPoseRoll.scalar  \
# 0                   100                    99                  100
# 1                   100                    99                  100
# 2                    98                    99                  100
# 3                   100                    99                  100
# 4                   100                    99                  100
# ..                  ...                   ...                  ...
# 103                 100                   100                  100
# 104                 100                    99                  100
# 105                 100                    97                  100
# 106                 100                    99                  100
# 107                 100                    97                  100
#
#      ExpressionNeutrality.scalar  NoHeadCoverings.scalar
# 0                             98                     100
# 1                             93                     100
# 2                             98                     100
# 3                             99                     100
# 4                             98                     100
# ..                           ...                     ...
# 103                           84                      87
# 104                           98                     100
# 105                           98                     100
# 106                           97                      61
# 107                           98                      99
#
# [108 rows x 30 columns]

# %% [markdown]
# Combine all the scalar values from `in_context_train` dataset into one column `OFIQResults`

# %%
df_in_context_train['OFIQResults'] = df_in_context_train.apply(
    lambda row: {col: row[col] for col in df_in_context_train.columns if col.endswith('scalar')}, axis=1
)
# Removing scalar columns
df_in_context_train = df_in_context_train.drop(columns=[col for col in df_in_context_train.columns if col.endswith('scalar')])

# %% [markdown]
# Provide the descriptions based on the contrast element using the function `generate_description`

# %%
from src.descriptions import generate_description


df_in_context_train['Description'] = df_in_context_train.apply(
    lambda row: generate_description(row['ContrastElement'], row['OFIQResults']), axis=1
)

show_columns = ['Filename', 'ContrastElement', 'Description']
pd.set_option('display.max_colwidth', None)
df_in_context_train[show_columns]
# Out:
#                                              Filename ContrastElement  \
# 0    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0005-F00.png            ONOT
# 1    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0051-F00.png            ONOT
# 2    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0062-F00.png            ONOT
# 3    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0034-F00.png            ONOT
# 4    S115379105-GF-A98-EEA-T14-S1-LH-C1-I0024-F00.png            ONOT
# ..                                                ...             ...
# 103  S248968574-GM-A81-EAS-T14-S1-LH-C1-I0022-F00.png            zoom
# 104  S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png            zoom
# 105  S265934537-GF-A26-EAS-T14-S1-LH-C1-I0063-F00.png            zoom
# 106  S220036139-GF-A33-EME-T14-S1-LH-C1-I0048-F00.png            zoom
# 107  S289919415-GF-A46-EEA-T14-S1-LH-C1-I0060-F00.png            zoom
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Description
# 0                                                                                                                                                                                                                                                                                                                                                                                                This image is excelent and fully complaint for biometric use. The face is perfectly centered and optimally cropped. No changes needed.
# 1                                                                                                                                                                                                                                                                                                                                                                                                This image is excelent and fully complaint for biometric use. The face is perfectly centered and optimally cropped. No changes needed.
# 2                                                                                                                                                                                                                                                                                                                                                                                                This image is excelent and fully complaint for biometric use. The face is perfectly centered and optimally cropped. No changes needed.
# 3                                                                                                                                                                                                                                                                                                                                                                                                This image is excelent and fully complaint for biometric use. The face is perfectly centered and optimally cropped. No changes needed.
# 4                                                                                                                                                                                                                                                                                                                                                                                                This image is excelent and fully complaint for biometric use. The face is perfectly centered and optimally cropped. No changes needed.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 103  The image is not compliant for biometric use. The image is improperly zoomed, with the head being too close to the camera appearing big (HeadSize.scalar: 26,InterEyeDistance.scalar: None ), and therefore loosing on sharpness (Sharpness.scalar: 95). It causes too small margins above (MarginAboveOfTheFaceImage.scalar: 0) and  below the face image (MarginBelowOfTheFaceImage.scalar: 1).   Actionable Feedback: Please zoom out to ensure the subject's face is properly framed with adequate margins and retake a photo.
# 104  The image is not compliant for biometric use. The image is improperly zoomed, with the head being too close to the camera appearing big (HeadSize.scalar: 83,InterEyeDistance.scalar: None ), and therefore loosing on sharpness (Sharpness.scalar: 27). It causes too small margins above (MarginAboveOfTheFaceImage.scalar: 0) and  below the face image (MarginBelowOfTheFaceImage.scalar: 4).   Actionable Feedback: Please zoom out to ensure the subject's face is properly framed with adequate margins and retake a photo.
# 105  The image is not compliant for biometric use. The image is improperly zoomed, with the head being too close to the camera appearing big (HeadSize.scalar: 67,InterEyeDistance.scalar: None ), and therefore loosing on sharpness (Sharpness.scalar: 25). It causes too small margins above (MarginAboveOfTheFaceImage.scalar: 1) and  below the face image (MarginBelowOfTheFaceImage.scalar: 0).   Actionable Feedback: Please zoom out to ensure the subject's face is properly framed with adequate margins and retake a photo.
# 106  The image is not compliant for biometric use. The image is improperly zoomed, with the head being too close to the camera appearing big (HeadSize.scalar: 88,InterEyeDistance.scalar: None ), and therefore loosing on sharpness (Sharpness.scalar: 9). It causes too small margins above (MarginAboveOfTheFaceImage.scalar: 0) and  below the face image (MarginBelowOfTheFaceImage.scalar: 17).   Actionable Feedback: Please zoom out to ensure the subject's face is properly framed with adequate margins and retake a photo.
# 107   The image is not compliant for biometric use. The image is improperly zoomed, with the head being too close to the camera appearing big (HeadSize.scalar: 53,InterEyeDistance.scalar: None ), and therefore loosing on sharpness (Sharpness.scalar: 9). It causes too small margins above (MarginAboveOfTheFaceImage.scalar: 0) and  below the face image (MarginBelowOfTheFaceImage.scalar: 2).   Actionable Feedback: Please zoom out to ensure the subject's face is properly framed with adequate margins and retake a photo.
#
# [108 rows x 3 columns]

# %% [markdown]
# The descriptions were manually checked and reviewed after generatic automatic descriptions

# %% [markdown]
# NOTE: In order to provide the valid description, the correlation diagram was created, to analyze which scalar values have the highest impact on different `ContrastElements`.

# %%
# Create a heatmap as a correlation matrix for each of the contrast elemnt which scalar values affect it the most in the df_combined

import seaborn as sns
import matplotlib.pyplot as plt 

df_combined_corr= df_combined.copy()
df_combined_corr = df_combined_corr.drop(columns=['Filename'])

# Do one-hot encoding for the ContrastElement column
df_combined_corr = pd.get_dummies(df_combined_corr, columns=['ContrastElement'])
correlation_matrix = df_combined_corr.corr()
plt.figure(figsize=(16, 12))
sns.heatmap(
    correlation_matrix,
    annot=True,
    fmt=".2f",
    cmap='coolwarm',
    square=True,
    cbar_kws={"shrink": .8},
    annot_kws={"size": 6}  # Smaller font size for numbers
)
plt.title('Correlation Matrix of Scalar Values')
plt.xticks(rotation=60, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()

# %% [markdown]
# As it can be observed bkg images are negativelly affected by the backround (-0.47)
# - cap negatively by NoHeadCovering (-0.92)
# - ce negatively by EyesOpenScalar (-60)
# - ceg negatively by EyesOpenScalar (-74)
# - expos negatively mostly by DynamicRange (-0.62), LuminanceMean (-0.5), LuminanceVariance (-0.4), UnderExposurePrevention (-0.3). Surprisingly overexposure has no impact on this dataset.
# - la1 and la2 don't have any strong correlations and therefore can be difficult to predict
# - light negatively by OverExposurePrevention (-0.83) and LuminanceVariance (-0.27)
# - mkup doesn't have strong correlations
# - oof negatively Sharpness (-0.66)
# - pixel no correlation
# - poster slight negative correlation with DynamicRange (-0.27)
# - sat with naturalcolor (-0.69)
# - sm with MouthClosed (-0.84) and ExpressionNeutrality (-0.79)
# - sun with EyesVisible (-0.99) and FaceOclussionPrevention (-0.83) and UnifiedQualityScore (-0.42)
# - tq (-0.72) HeadPoseYaw (-0.42) HeadPoseRoll
# - zoom HeadSize (0.62) and InterEyesDistance (0.53) sharpness (-0.5) MarginBelowFaceImage (-0.32) MarginAboveFaceImage (-0.3) and BackroundUniformity (-0.37)

# %% [markdown]
# ### Test data preparation

# %% [markdown]
# Choose a testing dataset from the `df_combined`. For testing purposes 2 images from each of the `ContrastElement` are being chosen in addition to 2 complaint images.

# %%
df_in_context_test = df_combined.copy()

# Removing images that are already in the training set, so we have a separate test set
df_in_context_test = df_in_context_test[~df_in_context_test['Filename'].isin(df_in_context_train['Filename'])]

# Grouping by ContrastElement and taking 2 images from each group
df_in_context_test = df_in_context_test.groupby('ContrastElement').head(2)

df_in_context_test
# Out:
#                                               Filename ContrastElement  \
# 2     S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_2
# 3     S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_2
# 305   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             sun
# 307   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0002-F00.png             sun
# 550   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            mkup
# 552   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0002-F00.png            mkup
# 747   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             oof
# 748   S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             oof
# 1058  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            zoom
# 1059  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            zoom
# 1369  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png              sm
# 1370  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png              sm
# 1676  S169208368-GM-A35-EME-T14-S1-LH-C1-I0063-F00.png              tq
# 1677       S0000-GF-A36-EIA-T02-S1-LH-C1-I0003-F00.png              tq
# 1828  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             bkg
# 1829  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             bkg
# 2097  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png           expos
# 2098  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png           expos
# 2407  S446421201-GM-A77-EME-T14-S1-LH-C1-I0048-F00.png           light
# 2409  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png           light
# 2558  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_1
# 2559  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_1
# 2866  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             sat
# 2867  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             sat
# 3177  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png              ce
# 3178  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png              ce
# 3421  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             cap
# 3422  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             cap
# 3709  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png          poster
# 3710  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png          poster
# 4020  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             ceg
# 4021  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             ceg
# 4260  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png           pixel
# 4261  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png           pixel
# 4569  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0019-F00.png            ONOT
# 4571  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0043-F00.png            ONOT
#
#       UnifiedQualityScore.scalar  BackgroundUniformity.scalar  \
# 2                             73                           84
# 3                             43                           83
# 305                           28                           84
# 307                           29                           83
# 550                           60                           84
# 552                           54                           83
# 747                           55                           91
# 748                           39                           89
# 1058                          62                           75
# 1059                          40                           85
# 1369                          86                           84
# 1370                          37                           84
# 1676                          62                           61
# 1677                          68                           80
# 1828                          60                           22
# 1829                          40                           80
# 2097                          30                           94
# 2098                          22                           94
# 2407                          26                           95
# 2409                          37                           83
# 2558                          66                           83
# 2559                          37                           83
# 2866                          58                           83
# 2867                          26                           83
# 3177                          70                           85
# 3178                          56                           84
# 3421                          41                           84
# 3422                          53                           80
# 3709                          61                           89
# 3710                          28                           85
# 4020                          39                           84
# 4021                          48                           83
# 4260                          60                           85
# 4261                          46                           85
# 4569                          66                           85
# 4571                          74                           85
#
#       IlluminationUniformity.scalar  LuminanceMean.scalar  \
# 2                                63                    99
# 3                                37                    99
# 305                              63                    98
# 307                              66                    94
# 550                              64                    99
# 552                              58                    96
# 747                              66                    99
# 748                              25                    99
# 1058                             67                    99
# 1059                             32                    99
# 1369                             65                    99
# 1370                             39                    99
# 1676                             75                    98
# 1677                             55                    89
# 1828                             66                    99
# 1829                             36                    99
# 2097                             75                    98
# 2098                             35                    15
# 2407                             86                    90
# 2409                              0                    99
# 2558                             68                    99
# 2559                             34                    99
# 2866                             55                    99
# 2867                             37                    99
# 3177                             62                    99
# 3178                             31                    99
# 3421                             66                    99
# 3422                             34                    99
# 3709                             59                   100
# 3710                             33                    99
# 4020                             63                    99
# 4021                             39                    99
# 4260                             67                    99
# 4261                             30                    99
# 4569                             63                    95
# 4571                             32                    99
#
#       LuminanceVariance.scalar  UnderExposurePrevention.scalar  \
# 2                           84                             100
# 3                           79                             100
# 305                         70                             100
# 307                         69                             100
# 550                         74                             100
# 552                         73                             100
# 747                         87                             100
# 748                         79                             100
# 1058                        86                             100
# 1059                        79                             100
# 1369                        84                             100
# 1370                        76                             100
# 1676                        56                             100
# 1677                        76                             100
# 1828                        86                             100
# 1829                        79                             100
# 2097                        98                             100
# 2098                        39                             100
# 2407                        87                             100
# 2409                        44                             100
# 2558                        86                             100
# 2559                        78                             100
# 2866                        66                             100
# 2867                        80                             100
# 3177                        85                             100
# 3178                        81                             100
# 3421                        83                             100
# 3422                        77                             100
# 3709                        78                             100
# 3710                        69                             100
# 4020                        91                             100
# 4021                        80                             100
# 4260                        86                             100
# 4261                        79                             100
# 4569                        82                             100
# 4571                        70                             100
#
#       OverExposurePrevention.scalar  DynamicRange.scalar  ...  \
# 2                               100                   94  ...
# 3                               100                   94  ...
# 305                             100                   93  ...
# 307                             100                   94  ...
# 550                             100                   94  ...
# 552                             100                   95  ...
# 747                             100                   93  ...
# 748                             100                   94  ...
# 1058                            100                   93  ...
# 1059                            100                   94  ...
# 1369                            100                   94  ...
# 1370                            100                   95  ...
# 1676                            100                   96  ...
# 1677                            100                   94  ...
# 1828                            100                   93  ...
# 1829                            100                   94  ...
# 2097                             99                   85  ...
# 2098                            100                   69  ...
# 2407                             95                   93  ...
# 2409                             10                   97  ...
# 2558                            100                   93  ...
# 2559                            100                   94  ...
# 2866                            100                   96  ...
# 2867                            100                   94  ...
# 3177                            100                   93  ...
# 3178                            100                   93  ...
# 3421                            100                   94  ...
# 3422                            100                   94  ...
# 3709                             99                   86  ...
# 3710                            100                   82  ...
# 4020                            100                   92  ...
# 4021                            100                   94  ...
# 4260                            100                   93  ...
# 4261                            100                   94  ...
# 4569                            100                   93  ...
# 4571                            100                   94  ...
#
#       HeadSize.scalar  LeftwardCropOfTheFaceImage.scalar  \
# 2                  14                                100
# 3                   8                                100
# 305                12                                100
# 307                22                                100
# 550                11                                100
# 552                17                                100
# 747                13                                100
# 748                 8                                100
# 1058               92                                100
# 1059               51                                100
# 1369               12                                100
# 1370                8                                100
# 1676               12                                100
# 1677                8                                100
# 1828               13                                100
# 1829                8                                100
# 2097               12                                100
# 2098                8                                100
# 2407               47                                100
# 2409                8                                100
# 2558               13                                100
# 2559                8                                100
# 2866               12                                100
# 2867                8                                100
# 3177               14                                100
# 3178               10                                100
# 3421               13                                100
# 3422                8                                100
# 3709               13                                100
# 3710                8                                100
# 4020               12                                100
# 4021                9                                100
# 4260               13                                100
# 4261                8                                100
# 4569                4                                100
# 4571                4                                100
#
#       RightwardCropOfTheFaceImage.scalar  MarginAboveOfTheFaceImage.scalar  \
# 2                                    100                                12
# 3                                    100                                63
# 305                                  100                                19
# 307                                  100                                 9
# 550                                  100                                23
# 552                                  100                                21
# 747                                  100                                14
# 748                                  100                                64
# 1058                                 100                                 0
# 1059                                 100                                 0
# 1369                                 100                                16
# 1370                                 100                                64
# 1676                                 100                                16
# 1677                                 100                                21
# 1828                                 100                                14
# 1829                                 100                                66
# 2097                                 100                                15
# 2098                                 100                                68
# 2407                                 100                                 4
# 2409                                 100                                66
# 2558                                 100                                14
# 2559                                 100                                66
# 2866                                 100                                16
# 2867                                 100                                63
# 3177                                 100                                10
# 3178                                 100                                44
# 3421                                 100                                15
# 3422                                 100                                64
# 3709                                 100                                15
# 3710                                 100                                63
# 4020                                 100                                18
# 4021                                 100                                50
# 4260                                 100                                14
# 4261                                 100                                63
# 4569                                 100                                38
# 4571                                 100                                27
#
#       MarginBelowOfTheFaceImage.scalar  HeadPoseYaw.scalar  \
# 2                                   77                 100
# 3                                   86                 100
# 305                                 83                 100
# 307                                 31                 100
# 550                                 83                 100
# 552                                 37                 100
# 747                                 80                 100
# 748                                 86                 100
# 1058                                19                 100
# 1059                                32                 100
# 1369                                84                 100
# 1370                                86                 100
# 1676                                83                  76
# 1677                                97                  94
# 1828                                80                 100
# 1829                                87                 100
# 2097                                82                 100
# 2098                                89                 100
# 2407                                 4                 100
# 2409                                87                 100
# 2558                                80                 100
# 2559                                87                 100
# 2866                                84                 100
# 2867                                86                 100
# 3177                                78                 100
# 3178                                81                 100
# 3421                                82                 100
# 3422                                86                 100
# 3709                                82                 100
# 3710                                86                 100
# 4020                                84                 100
# 4021                                84                 100
# 4260                                80                 100
# 4261                                86                 100
# 4569                               100                 100
# 4571                               100                 100
#
#       HeadPosePitch.scalar  HeadPoseRoll.scalar  ExpressionNeutrality.scalar  \
# 2                      100                  100                           98
# 3                       95                  100                           98
# 305                    100                  100                           94
# 307                    100                  100                           93
# 550                     99                  100                           96
# 552                    100                  100                           96
# 747                    100                  100                           99
# 748                     95                  100                           97
# 1058                   100                  100                           98
# 1059                    96                  100                           97
# 1369                   100                  100                           69
# 1370                    94                  100                           17
# 1676                    98                  100                           99
# 1677                    96                  100                           92
# 1828                   100                  100                           98
# 1829                    95                  100                           97
# 2097                   100                  100                           99
# 2098                    95                  100                           96
# 2407                   100                  100                           97
# 2409                    95                  100                           95
# 2558                   100                  100                           98
# 2559                    95                  100                           97
# 2866                   100                  100                           98
# 2867                    95                  100                           97
# 3177                    99                  100                           81
# 3178                    93                  100                           89
# 3421                   100                  100                           97
# 3422                    95                  100                           97
# 3709                   100                  100                           99
# 3710                    95                  100                           95
# 4020                    99                  100                           94
# 4021                    94                  100                           95
# 4260                   100                  100                           98
# 4261                    95                  100                           97
# 4569                    99                  100                           97
# 4571                   100                  100                           97
#
#       NoHeadCoverings.scalar
# 2                        100
# 3                        100
# 305                      100
# 307                      100
# 550                      100
# 552                      100
# 747                      100
# 748                      100
# 1058                      98
# 1059                     100
# 1369                     100
# 1370                     100
# 1676                     100
# 1677                     100
# 1828                     100
# 1829                     100
# 2097                     100
# 2098                     100
# 2407                     100
# 2409                     100
# 2558                     100
# 2559                     100
# 2866                     100
# 2867                     100
# 3177                     100
# 3178                     100
# 3421                       4
# 3422                       9
# 3709                     100
# 3710                     100
# 4020                     100
# 4021                     100
# 4260                     100
# 4261                     100
# 4569                     100
# 4571                     100
#
# [36 rows x 30 columns]

# %% [markdown]
# Combine all the scalar values from  `in_context_test` dataset into `OFIQResults`, so that it matches `in_context_train` dataset

# %%
df_in_context_test['OFIQResults'] = df_in_context_test.apply(
    lambda row: {col: row[col] for col in df_in_context_test.columns if col.endswith('scalar')}, axis=1
)
# Removing scalar columns
df_in_context_test = df_in_context_test.drop(columns=[col for col in df_in_context_test.columns if col.endswith('scalar')])

# %% [markdown]
# Add the descriptions to the `in_context_test` dataset that will be used for the further evaluation

# %%
df_in_context_test['Description'] = df_in_context_test.apply(
    lambda row: generate_description(row['ContrastElement'], row['OFIQResults']), axis=1
)

show_columns = ['Filename', 'ContrastElement', 'Description']
pd.set_option('display.max_colwidth', None)
df_in_context_test[show_columns]
# Out:
#                                               Filename ContrastElement  \
# 2     S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_2
# 3     S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_2
# 305   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             sun
# 307   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0002-F00.png             sun
# 550   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            mkup
# 552   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0002-F00.png            mkup
# 747   S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             oof
# 748   S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             oof
# 1058  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            zoom
# 1059  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            zoom
# 1369  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png              sm
# 1370  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png              sm
# 1676  S169208368-GM-A35-EME-T14-S1-LH-C1-I0063-F00.png              tq
# 1677       S0000-GF-A36-EIA-T02-S1-LH-C1-I0003-F00.png              tq
# 1828  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             bkg
# 1829  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             bkg
# 2097  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png           expos
# 2098  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png           expos
# 2407  S446421201-GM-A77-EME-T14-S1-LH-C1-I0048-F00.png           light
# 2409  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png           light
# 2558  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_1
# 2559  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_1
# 2866  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             sat
# 2867  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             sat
# 3177  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png              ce
# 3178  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png              ce
# 3421  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             cap
# 3422  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             cap
# 3709  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png          poster
# 3710  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png          poster
# 4020  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png             ceg
# 4021  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png             ceg
# 4260  S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png           pixel
# 4261  S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png           pixel
# 4569  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0019-F00.png            ONOT
# 4571  S115379105-GF-A98-EEA-T14-S1-LH-C1-I0043-F00.png            ONOT
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Description
# 2                                                                                                                                                                                                                                                     The image is not compliant for biometric use. The subject is looking away to the left. This deviation from a straight gaze is non-compliant. Actionable Feedback: Please change the subject to be looking straight ahead at the camera with a frontal head pose and retake a photo.
# 3                                                                                                                                                                                                                                                     The image is not compliant for biometric use. The subject is looking away to the left. This deviation from a straight gaze is non-compliant. Actionable Feedback: Please change the subject to be looking straight ahead at the camera with a frontal head pose and retake a photo.
# 305                                                                                                                                                                                                                                                          The image is not compliant for biometric use. The subject's face is occluded by sunglasses (FaceOcclusionPrevention.scalar: 75), specifically obscuring the eyes (EyesVisible.scalar: 0). Actionable Feedback: Please remove sunglasses from the subject and retake a photo.
# 307                                                                                                                                                                                                                                                         The image is not compliant for biometric use. The subject's face is occluded by sunglasses (FaceOcclusionPrevention.scalar: 74), specifically obscuring the eyes (EyesVisible.scalar: 11). Actionable Feedback: Please remove sunglasses from the subject and retake a photo.
# 550                                                                                                                                                                                                                                                               The image is not compliant for biometric use. The subject is wearing makeup, which may obscure facial features (FaceOcclusionPrevention.scalar: 99). This can impact biometric matching. Actionable Feedback: Please remove makeup from the subject and retake a photo.
# 552                                                                                                                                                                                                                                                               The image is not compliant for biometric use. The subject is wearing makeup, which may obscure facial features (FaceOcclusionPrevention.scalar: 98). This can impact biometric matching. Actionable Feedback: Please remove makeup from the subject and retake a photo.
# 747                                                                                                                                                                                                                                                                                                                       The image is not compliant for biometric use. The image is not sharp (score: 27), causing blurriness across facial features. Actionable Feedback: Please ensure proper focus on your camera and retake a photo.
# 748                                                                                                                                                                                                                                                                                                                        The image is not compliant for biometric use. The image is not sharp (score: 5), causing blurriness across facial features. Actionable Feedback: Please ensure proper focus on your camera and retake a photo.
# 1058  The image is not compliant for biometric use. The image is improperly zoomed, with the head being too close to the camera appearing big (HeadSize.scalar: 92,InterEyeDistance.scalar: None ), and therefore loosing on sharpness (Sharpness.scalar: 15). It causes too small margins above (MarginAboveOfTheFaceImage.scalar: 0) and  below the face image (MarginBelowOfTheFaceImage.scalar: 19).   Actionable Feedback: Please zoom out to ensure the subject's face is properly framed with adequate margins and retake a photo.
# 1059  The image is not compliant for biometric use. The image is improperly zoomed, with the head being too close to the camera appearing big (HeadSize.scalar: 51,InterEyeDistance.scalar: None ), and therefore loosing on sharpness (Sharpness.scalar: 18). It causes too small margins above (MarginAboveOfTheFaceImage.scalar: 0) and  below the face image (MarginBelowOfTheFaceImage.scalar: 32).   Actionable Feedback: Please zoom out to ensure the subject's face is properly framed with adequate margins and retake a photo.
# 1369                                                                                                                                                                                                                                               The image is not compliant for biometric use. The subject does not have a neutral facial expression (ExpressionNeutrality.scalar: 69), (MouthClosed.scalar: 89). Actionable Feedback: Please ensure the subject maintains a neutral expression with a closed mouth and retake a photo.
# 1370                                                                                                                                                                                                                                               The image is not compliant for biometric use. The subject does not have a neutral facial expression (ExpressionNeutrality.scalar: 17), (MouthClosed.scalar: 88). Actionable Feedback: Please ensure the subject maintains a neutral expression with a closed mouth and retake a photo.
# 1676                                                                                                                                                                                                                   The image is not compliant for biometric use. The subject's head pose is incorrect, with deviation from the center (HeadPoseYaw.scalar: 76, HeadPosePitch.scalar: 98, HeadPoseRoll.scalar: 100). Actionable Feedback: Please change the pose of the subject to be facing the camera directly and retake the photo.
# 1677                                                                                                                                                                                                                   The image is not compliant for biometric use. The subject's head pose is incorrect, with deviation from the center (HeadPoseYaw.scalar: 94, HeadPosePitch.scalar: 96, HeadPoseRoll.scalar: 100). Actionable Feedback: Please change the pose of the subject to be facing the camera directly and retake the photo.
# 1828                                                                                                                                                                                                                                   The image is not compliant for biometric use. The background is not uniform (BackroundUniformity.scalar: 22). This low score indicates inconsistencies or distracting elements in the background. Actionable Feedback: Please ensure a clean, plain, and consistent background and retake a photo.
# 1829                                                                                                                                                                                                                                   The image is not compliant for biometric use. The background is not uniform (BackroundUniformity.scalar: 80). This low score indicates inconsistencies or distracting elements in the background. Actionable Feedback: Please ensure a clean, plain, and consistent background and retake a photo.
# 2097                                                                                                                                  The image is not compliant for biometric use. There are exposure problems: the image is too dark (UnderExposurePrevention.scalar: 100) or too bright (LuminanceMean.scalar: 98) and (LuminanceVariance.scalar) . It can lead to a loss of detail in highlights or shadows (DynamicRange.scalar: 85). Actionable Feedback: Please ensure proper exposure settings in your camera and retake a photo.
# 2098                                                                                                                                  The image is not compliant for biometric use. There are exposure problems: the image is too dark (UnderExposurePrevention.scalar: 100) or too bright (LuminanceMean.scalar: 15) and (LuminanceVariance.scalar) . It can lead to a loss of detail in highlights or shadows (DynamicRange.scalar: 69). Actionable Feedback: Please ensure proper exposure settings in your camera and retake a photo.
# 2407                                                                                                                                                                                             The image is not compliant for biometric use. The face illumination is not uniform (IlluminationUniformity.scalar: 86) (OverExposurePrevention: 95). This low score indicates uneven lighting, causing harsh shadows or bright spots that obscure facial features. Actionable Feedback: Please use uniformed light and retake the photo.
# 2409                                                                                                                                                                                              The image is not compliant for biometric use. The face illumination is not uniform (IlluminationUniformity.scalar: 0) (OverExposurePrevention: 10). This low score indicates uneven lighting, causing harsh shadows or bright spots that obscure facial features. Actionable Feedback: Please use uniformed light and retake the photo.
# 2558                                                                                                                                                                                                                                                 The image is not compliant for biometric use. The subject is looking away to the right. This deviation from a straight gaze is non-compliant. Actionable Feedback: Please change the subject to be looking straight ahead at the camera with a frontal head pose and retake a photo.
# 2559                                                                                                                                                                                                                                                 The image is not compliant for biometric use. The subject is looking away to the right. This deviation from a straight gaze is non-compliant. Actionable Feedback: Please change the subject to be looking straight ahead at the camera with a frontal head pose and retake a photo.
# 2866                                                                                                                                                                                                                                          The image is not compliant for biometric use. The image colors are unnatural (NaturalColour.scalar: 97, appearing either too vivid or washed out. Actionable Feedback: Please ensure balanced color saturation and natural color reproduction in your camera settings and retake the photo.
# 2867                                                                                                                                                                                                                                          The image is not compliant for biometric use. The image colors are unnatural (NaturalColour.scalar: 37, appearing either too vivid or washed out. Actionable Feedback: Please ensure balanced color saturation and natural color reproduction in your camera settings and retake the photo.
# 3177                                                                                                                                                                                                                        The image is not compliant for biometric use. The subject has closed or partially closed eyes (EyesOpen.scalar: 50). This low score prevents proper detection of eye features crucial for recognition. Actionable Feedback: Please ensure the subject's eyes are clearly open and visible and retake a photo.
# 3178                                                                                                                                                                                                                        The image is not compliant for biometric use. The subject has closed or partially closed eyes (EyesOpen.scalar: 65). This low score prevents proper detection of eye features crucial for recognition. Actionable Feedback: Please ensure the subject's eyes are clearly open and visible and retake a photo.
# 3421                                                                                                                                                                                                                                                                                                      The image is not compliant for biometric use. The subject is wearing a head covering (NoHeadCoverings.scalar: 4), which is non-compliant. Actionable Feedback: Please remove head covering from the subject and retake a photo.
# 3422                                                                                                                                                                                                                                                                                                      The image is not compliant for biometric use. The subject is wearing a head covering (NoHeadCoverings.scalar: 9), which is non-compliant. Actionable Feedback: Please remove head covering from the subject and retake a photo.
# 3709                                                                                                                                                                                  The image is not compliant for biometric use. The image has posterization, indicating a loss of color depth and smooth tonal gradients . This can be caused by insufficient dynamic range capture (DynamicRange.scalar: 86). Actionable Feedback: Please ensure sufficient color depth and dynamic range in the camera settings and retake a photo.
# 3710                                                                                                                                                                                  The image is not compliant for biometric use. The image has posterization, indicating a loss of color depth and smooth tonal gradients . This can be caused by insufficient dynamic range capture (DynamicRange.scalar: 82). Actionable Feedback: Please ensure sufficient color depth and dynamic range in the camera settings and retake a photo.
# 4020                                                                                                                                                                         The image is not compliant for biometric use. The subject has closed or partially closed eyes and it wearing glasses (EyesOpen.scalar: 49). This low score prevents proper detection of eye features crucial for recognition. Actionable Feedback: Please ensure the subject's eyes are clearly open and visible, without any occlusions and retake a photo.
# 4021                                                                                                                                                                         The image is not compliant for biometric use. The subject has closed or partially closed eyes and it wearing glasses (EyesOpen.scalar: 38). This low score prevents proper detection of eye features crucial for recognition. Actionable Feedback: Please ensure the subject's eyes are clearly open and visible, without any occlusions and retake a photo.
# 4260                                                                                                                                                                                                                                                                                   The image is not compliant for biometric use. The image exhibits pixelation or low resolution artifacts. This impacts overall clarity and detail. Actionable Feedback: Please ensure high resolution and minimal compression and retake the photo.
# 4261                                                                                                                                                                                                                                                                                   The image is not compliant for biometric use. The image exhibits pixelation or low resolution artifacts. This impacts overall clarity and detail. Actionable Feedback: Please ensure high resolution and minimal compression and retake the photo.
# 4569                                                                                                                                                                                                                                                                                                                                                                                               This image is excelent and fully complaint for biometric use. The face is perfectly centered and optimally cropped. No changes needed.
# 4571                                                                                                                                                                                                                                                                                                                                                                                               This image is excelent and fully complaint for biometric use. The face is perfectly centered and optimally cropped. No changes needed.

# %% [markdown]
# Save the `in_context_test_evaluation` dataset and remove the descriptions, so that the LLM has a clean dataset

# %%
df_in_context_test_evaluation = df_in_context_test.copy()
df_in_context_test_= df_in_context_test.drop(columns=['Description'])

# Save the resulting DataFrame to a CSV file
df_in_context_test_evaluation.to_json('src/data/QFIQ_assessment/in_context_test_evaluation_data.jsonl', orient='records', lines=True, force_ascii=False)

# %% [markdown]
# Save both train and test datasets into the JSONL files

# %%
df_in_context_train.to_json('src/data/QFIQ_assessment/in_context_train_data.jsonl', orient='records', lines=True, force_ascii=False)
df_in_context_test.to_json('src/data/QFIQ_assessment/in_context_test_data.jsonl', orient='records', lines=True, force_ascii=False)

# %% [markdown]
# # We have LLama3.2 installed locally on the machine and will be calling it through the API

# %% [markdown]
# The LLM is started with the following command `ubuntu@denim:~$ ollama run llama3.2`

# %% [markdown]
# # Evaluation

# %% [markdown]
# The evaluation was performed on comparing descriptions generated by the LLM and the evaluation descriptions. `sentence-transformers` library was used https://pypi.org/project/sentence-transformers/ to calculate the similarity scores between descriptions

# %%
from src.evaluation import compare_descriptions

comparison_score = compare_descriptions('src/data/llm_descriptions/llm_generated_explanations.jsonl',
                                                'src/data/QFIQ_assessment/in_context_test_evaluation_data.jsonl', 
                                                )
df_comparison_score = pd.DataFrame(comparison_score)

mean_score = df_comparison_score['Similarity_Score'].mean()
std_score = df_comparison_score['Similarity_Score'].std()

print(f"Mean similarity score: {mean_score}")
print(f"Standard deviation of similarity scores: {std_score}")

mean_score_contrast = df_comparison_score.groupby('ContrastElement')['Similarity_Score'].mean().reset_index()

mean_score_contrast = mean_score_contrast.rename(columns={'Similarity_Score': 'Mean_Similarity_Score'})


mean_score_contrast
# Out:
# Mean similarity score: 0.6088940070735084
# Standard deviation of similarity scores: 0.03778877644805213
#    ContrastElement  Mean_Similarity_Score
# 0             ONOT               0.642090
# 1              bkg               0.636659
# 2              cap               0.598666
# 3               ce               0.588241
# 4              ceg               0.609853
# 5            expos               0.560456
# 6             la_1               0.576809
# 7             la_2               0.592838
# 8            light               0.620750
# 9             mkup               0.583608
# 10             oof               0.607428
# 11           pixel               0.606986
# 12          poster               0.591882
# 13             sat               0.618537
# 14              sm               0.587320
# 15             sun               0.652074
# 16              tq               0.654015
# 17            zoom               0.631880
