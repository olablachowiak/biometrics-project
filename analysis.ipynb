# %% [markdown]
# # Data Prepocessing

# %% [markdown]
# ## Show the output of the quality assesment on the TONO dataset

# %%
import pandas as pd

df = pd.read_csv('./tono_assessment.csv', delimiter=';')
# Remove the ../../src/data/TONO/release/ prefix from the Filename column rows
df['Filename'] = df['Filename'].str.replace(r'../../src/data/TONO/release/', '', regex=True)
df['ContrastElement'] = df['Filename'].str.split('/').str[0]
df['Filename'] = df['Filename'].str.replace(r'^[^/]+/', '', regex=True)
# Move the ContrastElement as a second column
df = df[['Filename', 'ContrastElement'] + [col for col in df.columns if col not in ['Filename', 'ContrastElement']]]
df
# Out:
#                                               Filename ContrastElement  \
# 0     S932980426-GM-A79-EME-T14-S1-LH-C1-I0014-F00.png            la_2
# 1     S397228464-GF-A72-EEA-T03-S1-LH-C1-I0009-F00.png            la_2
# 2     S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_2
# 3     S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_2
# 4     S334613033-GM-A58-EAF-T14-S1-LH-C1-I0047-F00.png            la_2
# ...                                                ...             ...
# 4564  S664246838-GF-A21-EEA-T11-S1-LH-C1-I0004-F00.png           pixel
# 4565  S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png           pixel
# 4566  S962503135-GF-A84-EEA-T14-S1-LH-C1-I0013-F00.png           pixel
# 4567  S415761895-GF-A62-EAS-T03-S1-LH-C1-I0005-F00.png           pixel
# 4568  S179182026-GM-A47-EEA-T11-S1-LH-C1-I0041-F00.png           pixel
#
#       UnifiedQualityScore  BackgroundUniformity  IlluminationUniformity  \
# 0               29.081543             23.828460                0.238281
# 1               25.214190             39.603437                0.209105
# 2               25.578022             32.657118                0.213958
# 3               22.214788             34.988555                0.037551
# 4               27.890985             45.059756                0.282007
# ...                   ...                   ...                     ...
# 4564            22.968184             49.203864                0.000000
# 4565            19.858953             34.097942                0.079620
# 4566            24.254084             69.027712                0.347755
# 4567            25.427649             25.253495                0.516204
# 4568            29.184067             36.674290                0.157025
#
#       LuminanceMean  LuminanceVariance  UnderExposurePrevention  \
# 0          0.310215           0.043742                 0.233351
# 1          0.417505           0.042918                 0.054696
# 2          0.476616           0.035719                 0.039281
# 3          0.447007           0.040772                 0.057592
# 4          0.260269           0.047316                 0.348876
# ...             ...                ...                      ...
# 4564       0.384795           0.044207                 0.074837
# 4565       0.349573           0.040303                 0.075974
# 4566       0.407682           0.037953                 0.063919
# 4567       0.471743           0.031344                 0.047019
# 4568       0.384651           0.032948                 0.064095
#
#       OverExposurePrevention  DynamicRange  ...  \
# 0                        0.0      7.463093  ...
# 1                        0.0      7.614437  ...
# 2                        0.0      7.488843  ...
# 3                        0.0      7.537620  ...
# 4                        0.0      7.329834  ...
# ...                      ...           ...  ...
# 4564                     0.0      7.505501  ...
# 4565                     0.0      7.540595  ...
# 4566                     0.0      7.549772  ...
# 4567                     0.0      7.346300  ...
# 4568                     0.0      7.449913  ...
#
#       RightwardCropOfTheFaceImage.scalar  MarginAboveOfTheFaceImage.scalar  \
# 0                                    100                                 6
# 1                                    100                                27
# 2                                    100                                12
# 3                                    100                                63
# 4                                    100                                 7
# ...                                  ...                               ...
# 4564                                 100                                14
# 4565                                 100                                70
# 4566                                 100                                86
# 4567                                 100                                48
# 4568                                 100                                 7
#
#       MarginBelowOfTheFaceImage.scalar  HeadPoseYaw.scalar  \
# 0                                    2                 100
# 1                                   97                 100
# 2                                   77                 100
# 3                                   86                 100
# 4                                   37                 100
# ...                                ...                 ...
# 4564                                28                 100
# 4565                                59                 100
# 4566                                63                 100
# 4567                                 9                 100
# 4568                                 7                 100
#
#       HeadPosePitch.scalar  HeadPoseRoll.scalar  ExpressionNeutrality.scalar  \
# 0                       98                  100                           95
# 1                      100                  100                           98
# 2                      100                  100                           98
# 3                       95                  100                           98
# 4                      100                  100                           96
# ...                    ...                  ...                          ...
# 4564                    98                  100                           97
# 4565                    99                  100                           98
# 4566                    99                  100                           98
# 4567                   100                  100                           98
# 4568                   100                  100                           99
#
#       NoHeadCoverings.scalar  assessment_time_in_ms  Unnamed: 58
# 0                        100                    677          NaN
# 1                        100                    504          NaN
# 2                        100                    443          NaN
# 3                        100                    462          NaN
# 4                        100                    434          NaN
# ...                      ...                    ...          ...
# 4564                     100                    434          NaN
# 4565                     100                    459          NaN
# 4566                     100                    461          NaN
# 4567                     100                    528          NaN
# 4568                     100                    575          NaN
#
# [4569 rows x 60 columns]

# %%
#

# %%
# Keep only the columns that output the scalar values, file names, and contrast elements
cols_to_keep = ['Filename', 'ContrastElement'] + [col for col in df.columns if col.endswith('scalar')]
df = df[cols_to_keep]
df
# Out:
#                                               Filename ContrastElement  \
# 0     S932980426-GM-A79-EME-T14-S1-LH-C1-I0014-F00.png            la_2
# 1     S397228464-GF-A72-EEA-T03-S1-LH-C1-I0009-F00.png            la_2
# 2     S673442144-GF-A53-EEA-T01-S1-LH-C1-I0028-F00.png            la_2
# 3     S411588159-GF-A21-EEA-T03-S1-LH-C1-I0033-F00.png            la_2
# 4     S334613033-GM-A58-EAF-T14-S1-LH-C1-I0047-F00.png            la_2
# ...                                                ...             ...
# 4564  S664246838-GF-A21-EEA-T11-S1-LH-C1-I0004-F00.png           pixel
# 4565  S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png           pixel
# 4566  S962503135-GF-A84-EEA-T14-S1-LH-C1-I0013-F00.png           pixel
# 4567  S415761895-GF-A62-EAS-T03-S1-LH-C1-I0005-F00.png           pixel
# 4568  S179182026-GM-A47-EEA-T11-S1-LH-C1-I0041-F00.png           pixel
#
#       UnifiedQualityScore.scalar  BackgroundUniformity.scalar  \
# 0                             91                           88
# 1                             70                           81
# 2                             73                           84
# 3                             43                           83
# 4                             87                           79
# ...                          ...                          ...
# 4564                          50                           77
# 4565                          23                           84
# 4566                          62                           68
# 4567                          72                           88
# 4568                          92                           82
#
#       IlluminationUniformity.scalar  LuminanceMean.scalar  \
# 0                                65                    90
# 1                                63                    99
# 2                                63                    99
# 3                                37                    99
# 4                                68                    77
# ...                             ...                   ...
# 4564                              0                    98
# 4565                             47                    95
# 4566                             73                    98
# 4567                             82                    99
# 4568                             57                    98
#
#       LuminanceVariance.scalar  UnderExposurePrevention.scalar  \
# 0                           76                             100
# 1                           77                             100
# 2                           84                             100
# 3                           79                             100
# 4                           73                             100
# ...                        ...                             ...
# 4564                        76                             100
# 4565                        80                             100
# 4566                        82                             100
# 4567                        89                             100
# 4568                        87                             100
#
#       OverExposurePrevention.scalar  DynamicRange.scalar  ...  \
# 0                               100                   93  ...
# 1                               100                   95  ...
# 2                               100                   94  ...
# 3                               100                   94  ...
# 4                               100                   92  ...
# ...                             ...                  ...  ...
# 4564                            100                   94  ...
# 4565                            100                   94  ...
# 4566                            100                   94  ...
# 4567                            100                   92  ...
# 4568                            100                   93  ...
#
#       HeadSize.scalar  LeftwardCropOfTheFaceImage.scalar  \
# 0                  51                                100
# 1                   8                                100
# 2                  14                                100
# 3                   8                                100
# 4                  22                                100
# ...               ...                                ...
# 4564               21                                100
# 4565               10                                100
# 4566                8                                100
# 4567               20                                100
# 4568               35                                100
#
#       RightwardCropOfTheFaceImage.scalar  MarginAboveOfTheFaceImage.scalar  \
# 0                                    100                                 6
# 1                                    100                                27
# 2                                    100                                12
# 3                                    100                                63
# 4                                    100                                 7
# ...                                  ...                               ...
# 4564                                 100                                14
# 4565                                 100                                70
# 4566                                 100                                86
# 4567                                 100                                48
# 4568                                 100                                 7
#
#       MarginBelowOfTheFaceImage.scalar  HeadPoseYaw.scalar  \
# 0                                    2                 100
# 1                                   97                 100
# 2                                   77                 100
# 3                                   86                 100
# 4                                   37                 100
# ...                                ...                 ...
# 4564                                28                 100
# 4565                                59                 100
# 4566                                63                 100
# 4567                                 9                 100
# 4568                                 7                 100
#
#       HeadPosePitch.scalar  HeadPoseRoll.scalar  ExpressionNeutrality.scalar  \
# 0                       98                  100                           95
# 1                      100                  100                           98
# 2                      100                  100                           98
# 3                       95                  100                           98
# 4                      100                  100                           96
# ...                    ...                  ...                          ...
# 4564                    98                  100                           97
# 4565                    99                  100                           98
# 4566                    99                  100                           98
# 4567                   100                  100                           98
# 4568                   100                  100                           99
#
#       NoHeadCoverings.scalar
# 0                        100
# 1                        100
# 2                        100
# 3                        100
# 4                        100
# ...                      ...
# 4564                     100
# 4565                     100
# 4566                     100
# 4567                     100
# 4568                     100
#
# [4569 rows x 30 columns]

# %% [markdown]
# For each of the contrast element group, 10 images will be chosen with the variety of the utility score for providing the testing base for the LLM

# %%
# Calculate the mean of the UnifiedQualityScore.scalar grouped by the Contrast Element
df_mean = df['UnifiedQualityScore.scalar'].groupby(df['ContrastElement']).median().reset_index()
df_mean
# Out:
#    ContrastElement  UnifiedQualityScore.scalar
# 0              bkg                        77.0
# 1              cap                        57.0
# 2               ce                        68.0
# 3              ceg                        46.0
# 4            expos                        52.0
# 5             la_1                        76.0
# 6             la_2                        75.0
# 7            light                        54.0
# 8             mkup                        55.0
# 9              oof                        72.0
# 10           pixel                        74.0
# 11          poster                        69.0
# 12             sat                        66.0
# 13              sm                        79.0
# 14             sun                        30.0
# 15              tq                        70.0
# 16            zoom                        74.0

# %%
# In each of the contrast elements group, get 3 images with the highest UnifiedQualityScore.scalar, 3 with the lowest UnifiedQualityScore.scalar, and 3 with the median UnifiedQualityScore.scalar. or closest to it.
def get_top_bottom_median(group):
    top = group.nlargest(2, 'UnifiedQualityScore.scalar')
    bottom = group.nsmallest(2, 'UnifiedQualityScore.scalar')
    median_value = group['UnifiedQualityScore.scalar'].median()
    median = group.iloc[(group['UnifiedQualityScore.scalar'] - median_value).abs().argsort()[:2]]
    
    return pd.concat([top, bottom, median])

# Apply the function to each group of ContrastElement
df_in_context_dataset = df.groupby('ContrastElement').apply(get_top_bottom_median).reset_index(drop=True)

# Save the resulting DataFrame to a CSV file
df_in_context_dataset.to_csv('tono_assessment_contrast_element_test.csv', index=False)
# Out:
# /tmp/ipykernel_12424/3100185993.py:11: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_in_context_dataset = df.groupby('ContrastElement').apply(get_top_bottom_median).reset_index(drop=True)

# %% [markdown]
# # In-context learning

# %% [markdown]
# Provide the descirption to the chosen test data set

# %%
# Read the saved CSV file
df_in_context_dataset = pd.read_csv('tono_assessment_contrast_element_test.csv')
df_in_context_dataset
# Out:
#                                              Filename ContrastElement  \
# 0    S744766748-GM-A69-EEA-T01-S1-LH-C1-I0008-F00.png             bkg
# 1    S115293589-GF-A67-EME-T01-S1-LH-C1-I0030-F00.png             bkg
# 2    S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png             bkg
# 3    S265934537-GF-A26-EAS-T14-S1-LH-C1-I0063-F00.png             bkg
# 4    S364995244-GM-A24-EEA-T03-S1-LH-C1-I0015-F00.png             bkg
# ..                                                ...             ...
# 97   S248968574-GM-A81-EAS-T14-S1-LH-C1-I0022-F00.png            zoom
# 98   S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png            zoom
# 99   S265934537-GF-A26-EAS-T14-S1-LH-C1-I0063-F00.png            zoom
# 100  S220036139-GF-A33-EME-T14-S1-LH-C1-I0048-F00.png            zoom
# 101  S289919415-GF-A46-EEA-T14-S1-LH-C1-I0060-F00.png            zoom
#
#      UnifiedQualityScore.scalar  BackgroundUniformity.scalar  \
# 0                            96                           40
# 1                            95                           90
# 2                            22                           85
# 3                            23                           85
# 4                            77                           84
# ..                          ...                          ...
# 97                           93                           58
# 98                           23                           74
# 99                           25                           66
# 100                          74                           81
# 101                          74                           59
#
#      IlluminationUniformity.scalar  LuminanceMean.scalar  \
# 0                               64                    96
# 1                               76                    99
# 2                               52                    95
# 3                               91                    99
# 4                               67                    99
# ..                             ...                   ...
# 97                              84                    97
# 98                              50                    95
# 99                              91                    99
# 100                             56                    99
# 101                             79                    99
#
#      LuminanceVariance.scalar  UnderExposurePrevention.scalar  \
# 0                          82                             100
# 1                          77                             100
# 2                          79                             100
# 3                          95                             100
# 4                          79                             100
# ..                        ...                             ...
# 97                         98                             100
# 98                         79                             100
# 99                         96                             100
# 100                        82                             100
# 101                        92                             100
#
#      OverExposurePrevention.scalar  DynamicRange.scalar  ...  HeadSize.scalar  \
# 0                              100                   93  ...               14
# 1                              100                   94  ...               57
# 2                              100                   94  ...               10
# 3                               99                   89  ...               15
# 4                              100                   94  ...               18
# ..                             ...                  ...  ...              ...
# 97                             100                   91  ...               26
# 98                             100                   94  ...               83
# 99                             100                   89  ...               67
# 100                            100                   94  ...               88
# 101                            100                   92  ...               53
#
#      LeftwardCropOfTheFaceImage.scalar  RightwardCropOfTheFaceImage.scalar  \
# 0                                  100                                 100
# 1                                  100                                 100
# 2                                  100                                 100
# 3                                  100                                 100
# 4                                  100                                 100
# ..                                 ...                                 ...
# 97                                 100                                 100
# 98                                 100                                 100
# 99                                 100                                 100
# 100                                100                                 100
# 101                                100                                 100
#
#      MarginAboveOfTheFaceImage.scalar  MarginBelowOfTheFaceImage.scalar  \
# 0                                  19                                66
# 1                                   2                                 3
# 2                                  70                                59
# 3                                  73                                10
# 4                                  31                                22
# ..                                ...                               ...
# 97                                  0                                 1
# 98                                  0                                 4
# 99                                  1                                 0
# 100                                 0                                17
# 101                                 0                                 2
#
#      HeadPoseYaw.scalar  HeadPosePitch.scalar  HeadPoseRoll.scalar  \
# 0                   100                    99                  100
# 1                   100                   100                  100
# 2                   100                    98                  100
# 3                   100                    97                  100
# 4                   100                    99                  100
# ..                  ...                   ...                  ...
# 97                  100                   100                  100
# 98                  100                    99                  100
# 99                  100                    97                  100
# 100                 100                    99                  100
# 101                 100                    97                  100
#
#      ExpressionNeutrality.scalar  NoHeadCoverings.scalar
# 0                             89                     100
# 1                             97                     100
# 2                             98                     100
# 3                             98                     100
# 4                             99                     100
# ..                           ...                     ...
# 97                            84                      87
# 98                            98                     100
# 99                            98                     100
# 100                           97                      61
# 101                           98                      99
#
# [102 rows x 30 columns]

# %% [markdown]
# Provide the descriptions based on the contrast element using manually added `description.py`

# %%
from src.scripts.description import generate_description

# Get the description for particular contrast elements
df_in_context_dataset['Description'] = df_in_context_dataset['ContrastElement'].astype(str).apply(generate_description)
show_columns = ['Filename', 'ContrastElement', 'UnifiedQualityScore.scalar', 'Description']
df_in_context_dataset[show_columns].head(10)

# Show the whole Description column output in the df using pandas
pd.set_option('display.max_colwidth', None)
df_in_context_dataset[show_columns].head(10)
# Out:
#                                            Filename ContrastElement  \
# 0  S744766748-GM-A69-EEA-T01-S1-LH-C1-I0008-F00.png             bkg
# 1  S115293589-GF-A67-EME-T01-S1-LH-C1-I0030-F00.png             bkg
# 2  S319441451-GF-A19-EAS-T01-S1-LH-C1-I0006-F00.png             bkg
# 3  S265934537-GF-A26-EAS-T14-S1-LH-C1-I0063-F00.png             bkg
# 4  S364995244-GM-A24-EEA-T03-S1-LH-C1-I0015-F00.png             bkg
# 5  S561424111-GM-A25-EME-T14-S1-LH-C1-I0010-F00.png             bkg
# 6  S710623010-GF-A75-EME-T01-S1-LH-C1-I0051-F00.png             cap
# 7  S115293589-GF-A67-EME-T01-S1-LH-C1-I0030-F00.png             cap
# 8  S409626024-GM-A29-EEA-T11-S1-LH-C1-I0000-F00.png             cap
# 9  S265934537-GF-A26-EAS-T14-S1-LH-C1-I0063-F00.png             cap
#
#    UnifiedQualityScore.scalar  \
# 0                          96
# 1                          95
# 2                          22
# 3                          23
# 4                          77
# 5                          77
# 6                          90
# 7                          89
# 8                          13
# 9                          22
#
#                                                                                                                                                                                               Description
# 0                                                        The image is not compliant for biometric use. The primary defect is: Background is not uniform. Please ensure a clean and consistent background.
# 1                                                        The image is not compliant for biometric use. The primary defect is: Background is not uniform. Please ensure a clean and consistent background.
# 2                                                        The image is not compliant for biometric use. The primary defect is: Background is not uniform. Please ensure a clean and consistent background.
# 3                                                        The image is not compliant for biometric use. The primary defect is: Background is not uniform. Please ensure a clean and consistent background.
# 4                                                        The image is not compliant for biometric use. The primary defect is: Background is not uniform. Please ensure a clean and consistent background.
# 5                                                        The image is not compliant for biometric use. The primary defect is: Background is not uniform. Please ensure a clean and consistent background.
# 6  The image is not compliant for biometric use. The primary defect is: Subject is wearing a head covering such as a hat, cap, bandana, bowler, or tifler. Please ensure the subject's head is uncovered.
# 7  The image is not compliant for biometric use. The primary defect is: Subject is wearing a head covering such as a hat, cap, bandana, bowler, or tifler. Please ensure the subject's head is uncovered.
# 8  The image is not compliant for biometric use. The primary defect is: Subject is wearing a head covering such as a hat, cap, bandana, bowler, or tifler. Please ensure the subject's head is uncovered.
# 9  The image is not compliant for biometric use. The primary defect is: Subject is wearing a head covering such as a hat, cap, bandana, bowler, or tifler. Please ensure the subject's head is uncovered.
